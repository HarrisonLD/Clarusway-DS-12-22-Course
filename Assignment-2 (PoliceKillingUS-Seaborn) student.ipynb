# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
# identify the unquie varaibles in the said column
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x = "gender", y ="age", hue = "manner_of_death", data=kill);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(12, 6))
sns.swarmplot(x = "gender", y ="age", 
              data=kill, hue='manner_of_death');

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
danger = kill["city"].value_counts().head(12)
danger
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot

fig, ax =plt.subplots(figsize=(8,5))

sns.barplot(x=danger.index, y=danger.values)
ax.set_title('Most dangerous cities', fontdict= { 'fontsize': 14, 'color':'b'})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45);

# %%
# with seaborn countplot

#create another dataframe to identfy top 12 danngerous cities
danger12 = kill[kill.city.isin(danger.index)]

#creating count plot
fig, ax =plt.subplots(figsize=(8,5))

sns.countplot(x="city", data=danger12, order=danger.index)
ax.set_title('Most dangerous cities', fontdict= { 'fontsize': 14, 'color':'b'})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45);

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
states= kill["state"].value_counts().head(20)
states
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))

sns.barplot(x=states.index, y=states.values)
ax.set_title('Most dangerous states', fontdict= { 'fontsize': 14, 'color':'b'})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45);

# %%
# with seaborn countplot
#create another dataframe to identfy top 12 danngerous cities
state12 = kill[kill.state.isin(states.index)]

#creating count plot
fig, ax =plt.subplots(figsize=(8,5))

sns.countplot(x="state", data=state12, order=states.index)
ax.set_title('Most dangerous states', fontdict= { 'fontsize': 14, 'color':'b'})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.head(3)
# Out:
#    id                name      date   manner_of_death    armed   age gender  \
# 0   3          Tim Elliot  02/01/15              shot      gun  53.0      M
# 1   4    Lewis Lee Lembke  02/01/15              shot      gun  47.0      M
# 2   5  John Paul Quintero  03/01/15  shot and Tasered  unarmed  23.0      M
#
#   race     city state  signs_of_mental_illness threat_level         flee  \
# 0    A  Shelton    WA                     True       attack  Not fleeing
# 1    W    Aloha    OR                    False       attack  Not fleeing
# 2    H  Wichita    KS                    False        other  Not fleeing
#
#    body_camera
# 0        False
# 1        False
# 2        False

# %%
mental = kill["signs_of_mental_illness"].value_counts()
mental
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn

ax=sns.barplot(x=mental.index, y=mental.values)

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threat = kill["threat_level"].value_counts()
threat
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn

ax=sns.barplot(x=threat.index, y=threat.values)

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_type = kill["flee"].value_counts()
flee_type
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
ax=sns.barplot(x=mental.index, y=mental.values)
